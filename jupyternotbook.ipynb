# %%
import pandas as pd
import numpy as np

df=pd.read_excel('covid_19_india.xls')
ad=df[["Confirmed","Deaths"]].drop_duplicates()
ad.shape
# Out:
# (406, 2)

# %%
histplot=df.hist(['Deaths','Confirmed'])

# %%
import pandas as pd 
agegd=pd.read_excel(r'C:\Users\NK VERMA\Desktop\covid19\AgeGroupDetails.xls')
print(agegd)
# Out:
#    Sno             AgeGroup  TotalCases  Percentage
# 0    1                  0-9          22      0.0318
# 1    2  2020-10-19 00:00:00          27      0.0390
# 2    3                20-29         172      0.2486
# 3    4                30-39         146      0.2110
# 4    5                40-49         112      0.1618
# 5    6                50-59          77      0.1113
# 6    7                60-69          89      0.1286
# 7    8                70-79          28      0.0405
# 8    9                 >=80          10      0.0145
# 9   10              Missing           9      0.0130

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_excel(r'C:\Users\NK VERMA\Desktop\covid19\AgeGroupDetails.xls')
num=df[['AgeGroup','TotalCases']]
a=num.plot.line(x='AgeGroup',y='TotalCases',rot=0)
plt.show()

# %%
import pandas as pd 
StatewiseTD=pd.read_excel(r'C:\Users\NK VERMA\Desktop\covid19\StatewiseTestingDetails.xls')
print(StatewiseTD)
# Out:
#           Date        State  TotalSamples  Negative  Positive
# 0   2020-02-17       Kerala           423     406.0         3
# 1   2020-02-18       Kerala           425     420.0         3
# 2   2020-02-19       Kerala           432     423.0         3
# 3   2020-02-20       Kerala           433     423.0         3
# 4   2020-02-21       Kerala           437     426.0         3
# ..         ...          ...           ...       ...       ...
# 196 2020-04-10       Odisha          3249    3201.0        48
# 197 2020-04-10       Punjab          3461    2972.0       151
# 198 2020-04-10    Rajasthan         22324   20673.0       520
# 199 2020-04-10   Tamil Nadu          8410    6838.0       911
# 200 2020-04-11  Maharashtra         31841   30477.0      1364
#
# [201 rows x 5 columns]

# %%
import pandas as pd

import numpy as np

df=StatewiseTD[["State","TotalSamples","Positive","Negative"]].drop_duplicates()
df.shape
# Out:
# (199, 4)

# %%
histplot=df.hist(['Positive','Negative'])

# %%
import pandas as pd
pop_india=pd.read_excel(r'C:\Users\NK VERMA\Desktop\covid19\population_india_census2011.xls')
print(pop_india)
# Out:
#     Sno                   State / Union Territory  Population  \
# 0     1                             Uttar Pradesh   199812341
# 1     2                               Maharashtra   112374333
# 2     3                                     Bihar   104099452
# 3     4                               West Bengal    91276115
# 4     5                            Madhya Pradesh    72626809
# 5     6                                Tamil Nadu    72147030
# 6     7                                 Rajasthan    68548437
# 7     8                                 Karnataka    61095297
# 8     9                                   Gujarat    60439692
# 9    10                            Andhra Pradesh    49577103
# 10   11                                    Odisha    41974218
# 11   12                                 Telengana    35003674
# 12   13                                    Kerala    33406061
# 13   14                                 Jharkhand    32988134
# ...

# %%
import numpy as np
df2=pop_india[['Population','Rural population','Urban population']]
df2.shape
# Out:
# (36, 3)

# %%
bot=df2.boxplot(['Population','Rural population','Urban population'])
